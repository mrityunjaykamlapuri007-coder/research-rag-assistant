# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/app.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/requirements.txt
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/ingestion.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/retriever.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/reranker.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/context_compressor.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/rag_chain.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-7/rag/src/evaluator.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-3/rag/app.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-3/rag/requirements.txt
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-3/rag/src/ingestion.py
# /kaggle/input/datasets/mrityunjayhelloworld/r-assist-3/rag/src/retriever.py
# ...

# %%
print(os.listdir('/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8'))

print(os.listdir('/kaggle/input/datasets/mrityunjayhelloworld/r-papers'))
# Out:
# ['rag']
# ['data']

# %%
print(os.listdir('/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8'))
print(os.listdir('/kaggle/input/datasets/mrityunjayhelloworld/r-papers/data'))
# Out:
# ['rag']
# ['papers']

# %%
# !pip install langchain langchain-community langchain-core faiss-cpu rank-bm25 pymupdf sentence-transformers transformers accelerate bitsandbytes huggingface_hub python-dotenv langchain-text-splitters

# %%
# !pip install -U langchain-huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
from huggingface_hub import login
login(token="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")

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="meta-llama/Meta-Llama-3.1-8B-Instruct",
    local_dir="/kaggle/working/models/llama-3.1-8b",
    ignore_patterns=["*.pt", "*.ot", "original/*"]
)
# Out:
# ...
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# '/kaggle/working/models/llama-3.1-8b'

# %%
import shutil

# %%
shutil.copytree("/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8", "/kaggle/working/src", dirs_exist_ok=True)
# Out:
# '/kaggle/working/src'

# %%
shutil.copy("/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8/rag/app.py", "/kaggle/working/app.py")
# Out:
# '/kaggle/working/app.py'

# %%
shutil.copy("/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8/rag/requirements.txt", "/kaggle/working/requirements.txt")
# Out:
# '/kaggle/working/requirements.txt'

# %%
os.makedirs("/kaggle/working/data/papers", exist_ok = True)

# %%
shutil.copytree("/kaggle/input/datasets/mrityunjayhelloworld/r-papers", "/kaggle/working/data/papers", dirs_exist_ok=True)
# Out:
# '/kaggle/working/data/papers'

# %%
# !ls /kaggle/working/
# Out:
# app.py	data  models  requirements.txt	src  vectorstore_backup.zip

# %%
# !ls /kaggle/working/data/papers/
# Out:
# data

# %%
os.chdir('/kaggle/working')

# %%
# !ls src/
# Out:
# rag

# %%
os.chdir('/kaggle/working/src/rag')

# %%
# !grep -n "PAPERS_DIR" src/ingestion.py
# Out:
# 12:PAPERS_DIR = "data/papers"
# 273:    pages_data = load_all_papers(PAPERS_DIR)

# %%
# !sed -i 's|PAPERS_DIR = "data/papers"|PAPERS_DIR = "/kaggle/working/data/papers/data/papers"|g' /kaggle/working/src/rag/src/ingestion.py

# %%
# !grep -n "PAPERS_DIR" src/ingestion.py
# Out:
# 12:PAPERS_DIR = "/kaggle/working/data/papers/data/papers"
# 273:    pages_data = load_all_papers(PAPERS_DIR)

# %%
# !ls /kaggle/working/data/papers/
# Out:
# data

# %%
# !ls /kaggle/working/data/papers/data/
# Out:
# papers

# %%
# !ls /kaggle/working/data/papers/data/papers/
# Out:
#  032902_1_online.pdf
#  084107_1_online.pdf
#  1-s2.0-S0022369719317330-main.pdf
#  1-s2.0-S0272884217325257-main.pdf
#  1-s2.0-S0272884218333601-main.pdf
#  1-s2.0-S0272884219327397-main.pdf
#  1-s2.0-S0925838821044881-main.pdf
#  1-s2.0-S0925838822024562-main.pdf
#  1-s2.0-S0925838824039318-main.pdf
#  1-s2.0-S095522191830757X-main.pdf
#  1-s2.0-S1359646224005281-main.pdf
#  1-s2.0-S2352847819301613-main.pdf
#  1-s2.0-S2772834X23000088-main.pdf
#  c3ce41594e.pdf
#  Cai_2017_J._Phys._D__Appl._Phys._50_155302.pdf
#  Enhancement-of-Piezoelectric-Properties-of-LiCePr-Multidoped-CaBi2Nb2O9-High-Temperature-Ceramics.pdf
# 'Journal of the American Ceramic Society - 2013 - Li - K  Na NbO3Based LeadFree Piezoceramics  Fundamental Aspects .pdf'
# 'Journal of the American Ceramic Society - 2018 - Liu - Enhanced thermal stability of  NaCe multidoped CaBi2Nb2O9 by Asite.pdf'
# ...

# %%
# %run src/ingestion.py
# Out:
# Starting Ingestion Pipeline
# Found 21 PDF files
# Processing: 1-s2.0-S2352847819301613-main.pdf
# Consider using the pymupdf_layout package for a greatly improved page layout analysis.
# Extracted 8 pages
# Processing: 1-s2.0-S0272884217325257-main.pdf
# Extracted 8 pages
# Processing: main.pdf
# Extracted 8 pages
# Processing: 032902_1_online.pdf
# Extracted 7 pages
# Processing: Enhancement-of-Piezoelectric-Properties-of-LiCePr-Multidoped-CaBi2Nb2O9-High-Temperature-Ceramics.pdf
# Extracted 5 pages
# Processing: c3ce41594e.pdf
# Extracted 11 pages
# Processing: 1-s2.0-S2772834X23000088-main.pdf
# Extracted 10 pages
# Processing: Journal of the American Ceramic Society - 2022 - Chen - Improving the piezoelectric properties of CBNbased ceramic by a Ce.pdf
# Extracted 10 pages
# Processing: Journal of the American Ceramic Society - 2018 - Liu - Enhanced thermal stability of  NaCe multidoped CaBi2Nb2O9 by Asite.pdf
# Extracted 12 pages
# Processing: 084107_1_online.pdf
# ...

# %%
# !grep -n "MODEL_PATH" src/rag_chain.py

# %%
# !sed -i 's|D:/research-rag/models/llama-3.1-8b|/kaggle/working/models/llama-3.1-8b|g' src/rag_chain.py

# %%
# !grep -n "MODEL_PATH" src/rag_chain.py

# %%
# !grep -n "MAX_TOKENS" src/rag_chain.py

# %%
# %run src/rag_chain.py

# %%
import sys

sys.path.append('/kaggle/input/datasets/mrityunjayhelloworld/r-assist-8/rag/src')
import ingestion

ingestion.PAPERS_DIR = '/kaggle/input/datasets/mrityunjayhelloworld/r-papers/data/papers'
ingestion.FAISS_INDEX_PATH = '/kaggle/working/src/rag/vectorstore/faiss_index'
ingestion.CHUNKS_METADATA_PATH = '/kaggle/working/src/rag/vectorstore/chunks.json'

if os.path.exists('/kaggle/working/src/rag/vectorstore'):
    shutil.rmtree('/kaggle/working/src/rag/vectorstore')
    print("old index deleted")

ingestion.run_ingestion()

shutil.make_archive('/kaggle/working/vectorstore_backup', 'zip', '/kaggle/working/src/rag/vectorstore')
print("Zipped successfully!")
# Out:
# old index deleted
# Starting Ingestion Pipeline
# Found 21 PDF files
# Processing: 1-s2.0-S0925838824039318-main.pdf
# Extracted 8 pages
# Processing: 1-s2.0-S095522191830757X-main.pdf
# Extracted 6 pages
# Processing: c3ce41594e.pdf
# Extracted 11 pages
# Processing: Enhancement-of-Piezoelectric-Properties-of-LiCePr-Multidoped-CaBi2Nb2O9-High-Temperature-Ceramics.pdf
# Extracted 5 pages
# Processing: Journal of the American Ceramic Society - 2018 - Liu - Enhanced thermal stability of  NaCe multidoped CaBi2Nb2O9 by Asite.pdf
# Extracted 12 pages
# Processing: 1-s2.0-S0925838821044881-main.pdf
# Extracted 9 pages
# Processing: Journal of the American Ceramic Society - 2022 - Chen - Improving the piezoelectric properties of CBNbased ceramic by a Ce.pdf
# Extracted 10 pages
# Processing: 1-s2.0-S1359646224005281-main.pdf
# Extracted 6 pages
# Processing: s10854-019-01534-3.pdf
# Extracted 8 pages
# Processing: 084107_1_online.pdf
# Extracted 8 pages
# ...

# %%
"""import importlib

sys.path.append('/kaggle/input/datasets/mrityunjayhelloworld/r-assist-4/rag/src')

import retriever
import context_compressor

importlib.reload(retriever)
importlib.reload(context_compressor)

print("Retriever reloaded — chunks:", len(retriever.chunks))
print("Context compressor reloaded — compression:", context_compressor.USE_COMPRESSION)
print("Done")"""

# %%
# !pip install rouge-score bert-score

# %%
# %run src/evaluator.py
# Out:
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-large
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading retriever resources...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# FAISS index loaded successfully
# BM25 index built successfully
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# ...
